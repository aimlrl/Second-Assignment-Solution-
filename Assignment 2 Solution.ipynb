# %%
import pandas as pd

# %%
data = pd.read_csv("mushrooms.csv")

# %%
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %% [markdown]
# Determine the value of:
#
# \begin{equation}
# P(cap-shape \cap cap-surface \cap cap-color | class)
# \end{equation}

# %% [markdown]
# Let's try answering the easy question first that suppose if you have been asked to compute the following Probability then what would you have done:
#
# \begin{equation}
# P(cap-shape=x \cap cap-surface=y \cap cap-color=w | class = e)
# \end{equation}
#
# That is Probability of picking up a mushroom whose cap-shape is x as well as cap-surface is y as well as cap-color is w provided (on a condition) that the mushroom belongs to 'e' class.
#
#                                                         OR
#
# The probability of picking up a 'e' class mushroom whose cap-shape is x as well as cap-surface is y as well as cap-color is w

# %% [markdown]
# We can say that event A can be represented as:
#
# \begin{equation}
# cap-shape=x \cap cap-surface=y \cap cap-color=w
# \end{equation}
#
# that is picking up a mushroom whose cap-shape is x, cap-surface is y and cap-color is w

# %% [markdown]
# Similarly, we can assume that we have another event B that can be represented as:
#
# \begin{equation}
# class = e
# \end{equation}
#
# that is picking up a mushroom whose class is e

# %% [markdown]
# So, now we can easily say that:
#
# \begin{equation}
# P(cap-shape=x \cap cap-surface=y \cap cap-color=w | class = e) = P(A|B)
# \end{equation}

# %% [markdown]
# Therefore, now according to the expression for conditional probability, we can say that:
#
# \begin{equation}
# P(A|B) = \frac{P(A \cap B)}{P(B)}
# \end{equation}

# %% [markdown]
# Now, following the above equation, we can write that:
#
# \begin{equation}
# P(cap-shape=x \cap cap-surface=y \cap cap-color=w | class=e) = \frac{P(cap-shape=x \cap cap-surface=y \cap cap-color=w \cap class=e)}{P(class=e)}
# \end{equation}

# %% [markdown]
# \begin{equation}
# P(cap-shape=x \cap cap-surface=y \cap cap-color=w \cap class=e)
# \end{equation}
#
# will be actually equal to:
#
# Relative Frequency of the number of mushrooms (number of rows in pandas dataframe) which are having all the four conditions satisfied at the same time (their cap-shape should be x, cap-surface should be y, cap-color should be w as well as they should be of e category)
#
# which will be furher equal to:
#
# \begin{equation}
# \frac{Frequency(cap-shape=x \cap cap-surface=y \cap cap-color=w \cap class=e)}{Total Number of Mushrooms}
# \end{equation}
#
# which will be further equal to:
#
# \begin{equation}
# \frac{Number of rows of pandas dataframe having cap-shape=x as well as cap-surface=y as well as cap-color=w as well as class=e}{Total number of rows in pandas dataframe}
# \end{equation}

# %% [markdown]
# Finding the number of rows satisftying the conditions mentioned in denominator

# %%
frequency = data[(data['cap-shape'] == 'x') & (data['cap-surface'] == 'y') & (data['cap-color'] == 'w') & (data['class'] == 'e')].shape[0]

# %%
total_mushrooms = data.shape[0]

# %%
numerator_joint_probability = frequency/total_mushrooms

# %%
numerator_joint_probability
# Out:
# 0.008862629246676515

# %% [markdown]
# \begin{equation}
# P(class=e)
# \end{equation}
#
# can be computed as:
#
# \begin{equation}
# \frac{Frequency(class=e)}{Total Number of Mushrooms}
# \end{equation}
#
# which can be further computed as:
#
# \begin{equation}
# \frac{Number of rows of pandas dataframe having e class mushrooms}{Total Number of Mushrooms}
# \end{equation}

# %%
frequency_e = data[data['class'] == 'e'].shape[0]

p_class_equals_e = frequency_e/total_mushrooms

# %%
conditional_probability = numerator_joint_probability/p_class_equals_e

# %%
conditional_probability
# Out:
# 0.01711026615969582

# %% [markdown]
# So, now we have to compute similarly:
#
# \begin{equation}
# P(cap-shape \cap cap-surface \cap cap-color | class)
# \end{equation}
#
# But, this time this is not going to be a probability, this is going to be a set of Probability Distributions.

# %% [markdown]
# Let's see how many unique values are there in each discrete random variables of cap-shape, cap-surface as well as cap-color accross your data

# %%
data['cap-shape'].unique()
# Out:
# array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object)

# %%
data['cap-surface'].unique()
# Out:
# array(['s', 'y', 'f', 'g'], dtype=object)

# %%
data['cap-color'].unique()
# Out:
# array(['n', 'y', 'w', 'g', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object)

# %%
data['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %% [markdown]
# Let's have a look on the data of poissonous class mushrooms

# %%
p_mushrooms_data = data[data['class'] == 'p']

# %%
p_mushrooms_data['cap-shape'].unique()
# Out:
# array(['x', 'f', 'b', 'k', 'c'], dtype=object)

# %% [markdown]
# It can be clearly observed that in p category mushrooms, cap shape of s is not there. It means that among the whole sample data, we were manage to get even a single p category mushroom which is having 's' cap shape therefore, it's Frequency is going to be zero. Which means that suppose if we compute the following probability:
#
# \begin{equation}
# P(cap-shape=s \cap cap-surface=any \cap cap-color=any | class=p) = \frac{Frequency(cap-shape=s \cap capsurface=any \cap cap-color=any) for p category mushrooms}{Number of p category mushrooms}
# \end{equation}
#
# Then this probability will be equal to zero because none of the p category mushrooms have cap shape as s

# %% [markdown]
# Here, we can compute this probability and say that its zero but not in Naive Bayes Classification. There, we have to smoothen out our hard probability of zero by either laplace smoothing or lidstone smoothing.

# %%
conditional_probabilities = {}

for cls in data['class'].unique():
    
    for cap_shape in data['cap-shape'].unique():
    
        for cap_surface in data['cap-surface'].unique():
        
            for cap_color in data['cap-color'].unique():
                
                conditional_prob = data[(data['cap-shape'] == cap_shape) & (data['cap-surface'] == cap_surface) & (data['cap-color'] == cap_color) & (data['class'] == cls)].shape[0]/data[data['class'] == cls].shape[0]
                
                key_string = "P("+"cap-shape={}".format(cap_shape)+" and cap-surface={}".format(cap_surface)+" and cap-color={}".format(cap_color)+" | class ={}".format(cls)+")"
                
                conditional_probabilities[key_string] = conditional_prob

# %%
conditional_probabilities
# Out:
# {'P(cap-shape=x and cap-surface=s and cap-color=n | class =p)': 0.0449438202247191,
#  'P(cap-shape=x and cap-surface=s and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=s and cap-color=w | class =p)': 0.028600612870275793,
#  'P(cap-shape=x and cap-surface=s and cap-color=g | class =p)': 0.020429009193054137,
#  'P(cap-shape=x and cap-surface=s and cap-color=e | class =p)': 0.03677221654749745,
#  'P(cap-shape=x and cap-surface=s and cap-color=p | class =p)': 0.008171603677221655,
#  'P(cap-shape=x and cap-surface=s and cap-color=b | class =p)': 0.012257405515832482,
#  'P(cap-shape=x and cap-surface=s and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=s and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=s and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=y and cap-color=n | class =p)': 0.04647599591419816,
#  'P(cap-shape=x and cap-surface=y and cap-color=y | class =p)': 0.04187946884576098,
#  'P(cap-shape=x and cap-surface=y and cap-color=w | class =p)': 0.008171603677221655,
#  'P(cap-shape=x and cap-surface=y and cap-color=g | class =p)': 0.04136874361593463,
#  'P(cap-shape=x and cap-surface=y and cap-color=e | class =p)': 0.03779366700715015,
#  'P(cap-shape=x and cap-surface=y and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=y and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=y and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=y and cap-color=c | class =p)': 0.0010214504596527069,
#  'P(cap-shape=x and cap-surface=y and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=n | class =p)': 0.0005107252298263534,
#  'P(cap-shape=x and cap-surface=f and cap-color=y | class =p)': 0.04187946884576098,
#  'P(cap-shape=x and cap-surface=f and cap-color=w | class =p)': 0.008171603677221655,
#  'P(cap-shape=x and cap-surface=f and cap-color=g | class =p)': 0.04954034729315628,
#  'P(cap-shape=x and cap-surface=f and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=p | class =p)': 0.008171603677221655,
#  'P(cap-shape=x and cap-surface=f and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=w | class =p)': 0.0015321756894790602,
#  'P(cap-shape=b and cap-surface=s and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=p | class =p)': 0.0015321756894790602,
#  'P(cap-shape=b and cap-surface=s and cap-color=b | class =p)': 0.0015321756894790602,
#  'P(cap-shape=b and cap-surface=s and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=n | class =p)': 0.0005107252298263534,
#  'P(cap-shape=b and cap-surface=y and cap-color=y | class =p)': 0.0010214504596527069,
#  'P(cap-shape=b and cap-surface=y and cap-color=w | class =p)': 0.001787538304392237,
#  'P(cap-shape=b and cap-surface=y and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=p | class =p)': 0.0015321756894790602,
#  'P(cap-shape=b and cap-surface=y and cap-color=b | class =p)': 0.0015321756894790602,
#  'P(cap-shape=b and cap-surface=y and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=n | class =p)': 0.0005107252298263534,
#  'P(cap-shape=b and cap-surface=f and cap-color=y | class =p)': 0.0005107252298263534,
#  'P(cap-shape=b and cap-surface=f and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=w | class =p)': 0.0002553626149131767,
#  'P(cap-shape=b and cap-surface=g and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=s and cap-color=n | class =p)': 0.0449438202247191,
#  'P(cap-shape=f and cap-surface=s and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=s and cap-color=w | class =p)': 0.021961184882533197,
#  'P(cap-shape=f and cap-surface=s and cap-color=g | class =p)': 0.012257405515832482,
#  'P(cap-shape=f and cap-surface=s and cap-color=e | class =p)': 0.03677221654749745,
#  'P(cap-shape=f and cap-surface=s and cap-color=p | class =p)': 0.0015321756894790602,
#  'P(cap-shape=f and cap-surface=s and cap-color=b | class =p)': 0.013789581205311542,
#  'P(cap-shape=f and cap-surface=s and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=s and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=s and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=y and cap-color=n | class =p)': 0.04647599591419816,
#  'P(cap-shape=f and cap-surface=y and cap-color=y | class =p)': 0.042390194075587334,
#  'P(cap-shape=f and cap-surface=y and cap-color=w | class =p)': 0.009959141981613892,
#  'P(cap-shape=f and cap-surface=y and cap-color=g | class =p)': 0.04136874361593463,
#  'P(cap-shape=f and cap-surface=y and cap-color=e | class =p)': 0.03779366700715015,
#  'P(cap-shape=f and cap-surface=y and cap-color=p | class =p)': 0.0015321756894790602,
#  'P(cap-shape=f and cap-surface=y and cap-color=b | class =p)': 0.0015321756894790602,
#  'P(cap-shape=f and cap-surface=y and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=y and cap-color=c | class =p)': 0.0010214504596527069,
#  'P(cap-shape=f and cap-surface=y and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=n | class =p)': 0.0005107252298263534,
#  'P(cap-shape=f and cap-surface=f and cap-color=y | class =p)': 0.04187946884576098,
#  'P(cap-shape=f and cap-surface=f and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=g | class =p)': 0.04136874361593463,
#  'P(cap-shape=f and cap-surface=f and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=w | class =p)': 0.0002553626149131767,
#  'P(cap-shape=f and cap-surface=g and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=n | class =p)': 0.03677221654749745,
#  'P(cap-shape=k and cap-surface=s and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=e | class =p)': 0.03677221654749745,
#  'P(cap-shape=k and cap-surface=s and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=n | class =p)': 0.03830439223697651,
#  'P(cap-shape=k and cap-surface=y and cap-color=y | class =p)': 0.0010214504596527069,
#  'P(cap-shape=k and cap-surface=y and cap-color=w | class =p)': 0.0002553626149131767,
#  'P(cap-shape=k and cap-surface=y and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=e | class =p)': 0.03779366700715015,
#  'P(cap-shape=k and cap-surface=y and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=c | class =p)': 0.0010214504596527069,
#  'P(cap-shape=k and cap-surface=y and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=n | class =p)': 0.0005107252298263534,
#  'P(cap-shape=k and cap-surface=f and cap-color=y | class =p)': 0.0005107252298263534,
#  'P(cap-shape=k and cap-surface=f and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=w | class =p)': 0.0002553626149131767,
#  'P(cap-shape=k and cap-surface=g and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=y | class =p)': 0.0005107252298263534,
#  'P(cap-shape=c and cap-surface=y and cap-color=w | class =p)': 0.0002553626149131767,
#  'P(cap-shape=c and cap-surface=y and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=w | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=n | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=y | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=w | class =p)': 0.0002553626149131767,
#  'P(cap-shape=c and cap-surface=g and cap-color=g | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=e | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=p | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=b | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=u | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=c | class =p)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=r | class =p)': 0.0,
#  'P(cap-shape=x and cap-surface=s and cap-color=n | class =e)': 0.029467680608365018,
#  'P(cap-shape=x and cap-surface=s and cap-color=y | class =e)': 0.01806083650190114,
#  'P(cap-shape=x and cap-surface=s and cap-color=w | class =e)': 0.03897338403041825,
#  'P(cap-shape=x and cap-surface=s and cap-color=g | class =e)': 0.02138783269961977,
#  'P(cap-shape=x and cap-surface=s and cap-color=e | class =e)': 0.0019011406844106464,
#  'P(cap-shape=x and cap-surface=s and cap-color=p | class =e)': 0.002376425855513308,
#  'P(cap-shape=x and cap-surface=s and cap-color=b | class =e)': 0.0019011406844106464,
#  'P(cap-shape=x and cap-surface=s and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=s and cap-color=c | class =e)': 0.0004752851711026616,
#  'P(cap-shape=x and cap-surface=s and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=y and cap-color=n | class =e)': 0.049429657794676805,
#  'P(cap-shape=x and cap-surface=y and cap-color=y | class =e)': 0.026615969581749048,
#  'P(cap-shape=x and cap-surface=y and cap-color=w | class =e)': 0.017110266159695818,
#  'P(cap-shape=x and cap-surface=y and cap-color=g | class =e)': 0.034695817490494295,
#  'P(cap-shape=x and cap-surface=y and cap-color=e | class =e)': 0.03612167300380228,
#  'P(cap-shape=x and cap-surface=y and cap-color=p | class =e)': 0.002376425855513308,
#  'P(cap-shape=x and cap-surface=y and cap-color=b | class =e)': 0.0019011406844106464,
#  'P(cap-shape=x and cap-surface=y and cap-color=u | class =e)': 0.0019011406844106464,
#  'P(cap-shape=x and cap-surface=y and cap-color=c | class =e)': 0.0014258555133079848,
#  'P(cap-shape=x and cap-surface=y and cap-color=r | class =e)': 0.0019011406844106464,
#  'P(cap-shape=x and cap-surface=f and cap-color=n | class =e)': 0.05418250950570342,
#  'P(cap-shape=x and cap-surface=f and cap-color=y | class =e)': 0.0028517110266159697,
#  'P(cap-shape=x and cap-surface=f and cap-color=w | class =e)': 0.02376425855513308,
#  'P(cap-shape=x and cap-surface=f and cap-color=g | class =e)': 0.058935361216730035,
#  'P(cap-shape=x and cap-surface=f and cap-color=e | class =e)': 0.034220532319391636,
#  'P(cap-shape=x and cap-surface=f and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=f and cap-color=c | class =e)': 0.0009505703422053232,
#  'P(cap-shape=x and cap-surface=f and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=x and cap-surface=g and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=n | class =e)': 0.01188212927756654,
#  'P(cap-shape=b and cap-surface=s and cap-color=y | class =e)': 0.015209125475285171,
#  'P(cap-shape=b and cap-surface=s and cap-color=w | class =e)': 0.02091254752851711,
#  'P(cap-shape=b and cap-surface=s and cap-color=g | class =e)': 0.005703422053231939,
#  'P(cap-shape=b and cap-surface=s and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=s and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=n | class =e)': 0.0004752851711026616,
#  'P(cap-shape=b and cap-surface=y and cap-color=y | class =e)': 0.015209125475285171,
#  'P(cap-shape=b and cap-surface=y and cap-color=w | class =e)': 0.015209125475285171,
#  'P(cap-shape=b and cap-surface=y and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=y and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=w | class =e)': 0.005703422053231939,
#  'P(cap-shape=b and cap-surface=f and cap-color=g | class =e)': 0.005703422053231939,
#  'P(cap-shape=b and cap-surface=f and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=f and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=b and cap-surface=g and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=s and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=y and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=n | class =e)': 0.0038022813688212928,
#  'P(cap-shape=s and cap-surface=f and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=g | class =e)': 0.0038022813688212928,
#  'P(cap-shape=s and cap-surface=f and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=f and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=s and cap-surface=g and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=s and cap-color=n | class =e)': 0.029467680608365018,
#  'P(cap-shape=f and cap-surface=s and cap-color=y | class =e)': 0.0028517110266159697,
#  'P(cap-shape=f and cap-surface=s and cap-color=w | class =e)': 0.01806083650190114,
#  'P(cap-shape=f and cap-surface=s and cap-color=g | class =e)': 0.01568441064638783,
#  'P(cap-shape=f and cap-surface=s and cap-color=e | class =e)': 0.0019011406844106464,
#  'P(cap-shape=f and cap-surface=s and cap-color=p | class =e)': 0.002376425855513308,
#  'P(cap-shape=f and cap-surface=s and cap-color=b | class =e)': 0.0019011406844106464,
#  'P(cap-shape=f and cap-surface=s and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=s and cap-color=c | class =e)': 0.0004752851711026616,
#  'P(cap-shape=f and cap-surface=s and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=y and cap-color=n | class =e)': 0.049429657794676805,
#  'P(cap-shape=f and cap-surface=y and cap-color=y | class =e)': 0.011406844106463879,
#  'P(cap-shape=f and cap-surface=y and cap-color=w | class =e)': 0.0019011406844106464,
#  'P(cap-shape=f and cap-surface=y and cap-color=g | class =e)': 0.034695817490494295,
#  'P(cap-shape=f and cap-surface=y and cap-color=e | class =e)': 0.03612167300380228,
#  'P(cap-shape=f and cap-surface=y and cap-color=p | class =e)': 0.002376425855513308,
#  'P(cap-shape=f and cap-surface=y and cap-color=b | class =e)': 0.0019011406844106464,
#  'P(cap-shape=f and cap-surface=y and cap-color=u | class =e)': 0.0019011406844106464,
#  'P(cap-shape=f and cap-surface=y and cap-color=c | class =e)': 0.0014258555133079848,
#  'P(cap-shape=f and cap-surface=y and cap-color=r | class =e)': 0.0019011406844106464,
#  'P(cap-shape=f and cap-surface=f and cap-color=n | class =e)': 0.05418250950570342,
#  'P(cap-shape=f and cap-surface=f and cap-color=y | class =e)': 0.0028517110266159697,
#  'P(cap-shape=f and cap-surface=f and cap-color=w | class =e)': 0.01806083650190114,
#  'P(cap-shape=f and cap-surface=f and cap-color=g | class =e)': 0.053231939163498096,
#  'P(cap-shape=f and cap-surface=f and cap-color=e | class =e)': 0.034220532319391636,
#  'P(cap-shape=f and cap-surface=f and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=f and cap-color=c | class =e)': 0.0009505703422053232,
#  'P(cap-shape=f and cap-surface=f and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=f and cap-surface=g and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=n | class =e)': 0.013783269961977186,
#  'P(cap-shape=k and cap-surface=s and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=w | class =e)': 0.005703422053231939,
#  'P(cap-shape=k and cap-surface=s and cap-color=g | class =e)': 0.005703422053231939,
#  'P(cap-shape=k and cap-surface=s and cap-color=e | class =e)': 0.0019011406844106464,
#  'P(cap-shape=k and cap-surface=s and cap-color=p | class =e)': 0.0019011406844106464,
#  'P(cap-shape=k and cap-surface=s and cap-color=b | class =e)': 0.0019011406844106464,
#  'P(cap-shape=k and cap-surface=s and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=s and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=n | class =e)': 0.003326996197718631,
#  'P(cap-shape=k and cap-surface=y and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=e | class =e)': 0.0019011406844106464,
#  'P(cap-shape=k and cap-surface=y and cap-color=p | class =e)': 0.0019011406844106464,
#  'P(cap-shape=k and cap-surface=y and cap-color=b | class =e)': 0.0019011406844106464,
#  'P(cap-shape=k and cap-surface=y and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=y and cap-color=c | class =e)': 0.0009505703422053232,
#  'P(cap-shape=k and cap-surface=y and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=n | class =e)': 0.0009505703422053232,
#  'P(cap-shape=k and cap-surface=f and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=w | class =e)': 0.005703422053231939,
#  'P(cap-shape=k and cap-surface=f and cap-color=g | class =e)': 0.005703422053231939,
#  'P(cap-shape=k and cap-surface=f and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=f and cap-color=c | class =e)': 0.0009505703422053232,
#  'P(cap-shape=k and cap-surface=f and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=k and cap-surface=g and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=s and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=y and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=f and cap-color=r | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=n | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=y | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=w | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=g | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=e | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=p | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=b | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=u | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=c | class =e)': 0.0,
#  'P(cap-shape=c and cap-surface=g and cap-color=r | class =e)': 0.0}
